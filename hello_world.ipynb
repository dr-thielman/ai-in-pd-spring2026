# %% [markdown]
# # Hello ME 493B
#
# Welcome to the course repo for **ME 493B — AI in Product Development**.
#
# The purpose of this notebook is to confirm your development environment works before the real work begins. There is nothing to turn in beyond proof that you completed it — this is a setup check, not a graded project.
#
# ## The loop you'll use all quarter
#
# > **Canvas** tells you what to do → **GitHub** is where you do it → **Canvas** is where you submit proof → **Canvas** is where you see your grade
#
# Every assignment follows this pattern. By the end of this notebook, you'll have practiced it once.
#
# ## About this notebook
#
# This notebook was generated from a specification. Take a look at `specs/SPEC_hello_world.md` after you finish. One of the skills you'll develop in this course is writing specifications like that one to direct AI tools toward engineering outcomes. That's the **Goal & Direction** pillar — and you'll be doing it yourself starting with MP1.
#
# **Estimated time:** 20–30 minutes

# %% [markdown]
# ## How to use this notebook
#
# - Run cells top to bottom using **Shift+Enter** or the ▶ button
# - **Code cells** marked `# TODO`: type the comment, wait for Copilot to suggest code (ghost text), then press **Tab** to accept
# - **Markdown cells** marked ✏️ **EDIT THIS CELL**: click to edit, fill in your answer, then run the cell to render it
# - If Copilot isn't suggesting anything: confirm the Copilot extension is enabled in the VS Code sidebar

# %% [markdown]
# ### Section 1 — Confirm your environment

# %%
# TODO: print a friendly message that includes: your name (hardcode
# it as a variable called student_name), Python version from sys,
# numpy version, and matplotlib version

# %% [markdown]
# ### Section 2 — Your first plot

# %%
# TODO: plot one full cycle of a sine wave using numpy and matplotlib.
# x-axis label: "Angle (radians)", y-axis label: "Amplitude"
# Title: "Hello ME 493B — " + student_name

# %% [markdown]
# ### Section 3 — Copilot exercise
#
# In this section you'll give Copilot a comment describing what you want, accept its suggestion, and run it. This is the core interaction you'll use throughout the course. You direct. Copilot drafts. You evaluate and refine.
#
# Type the comment below slowly, pause, wait for the ghost text, and press **Tab** to accept.

# %%
# TODO: generate 100 random numbers from a normal distribution
# and plot a histogram with 15 bins. Add a title and axis labels.

# %% [markdown]
# ### ✏️ EDIT THIS CELL — Section 4: Reflection
#
# **Name:**
#
# **What did Copilot suggest for the histogram cell?** (describe in one sentence — you don't need to copy the code)
#
#
# **Did the suggestion work as-is, or did you need to modify it?**
#
#
# **One question or uncertainty you have entering this course:**

# %% [markdown]
# ### Section 5 — Save and submit your work
#
# **Step 1: Confirm all cells have run**
#
# No `[*]` indicators should be visible. All outputs should be visible below each code cell.
#
# **Step 2: Open the Source Control panel**
#
# Click the branch icon in the left sidebar (it looks like a forked path). You should see `hello_world.ipynb` listed under **Changes**.
#
# **Step 3: Stage your file**
#
# Click the **+** icon next to `hello_world.ipynb` to stage it. It will move to **Staged Changes**.
#
# **Step 4: Write a commit message**
#
# In the message box at the top, type exactly:
#
#     hello_world complete — [Your Name]
#
# Replace `[Your Name]` with your actual name.
#
# **Step 5: Commit and push**
#
# Click the **✓ Commit** button, then click **Sync Changes** (or the cloud/push icon that appears). Your work is now saved to GitHub.
#
# **Step 6: Get your repo URL**
#
# In the Codespaces terminal (Terminal → New Terminal), type:
#
#     git remote get-url origin
#
# Copy the URL that appears.
#
# **Step 7: Submit to Canvas**
#
# Go to the Canvas assignment page for Hello World Setup. Paste your repo URL into the **Website URL** submission field. Click **Submit**.

# %% [markdown]
# ### You're ready
#
# If you made it here, your environment is set up and you know the submission workflow. Both will serve you all quarter.
#
# Before you close this notebook, open `specs/SPEC_hello_world.md` and read through it. Notice how the specification describes intent and structure without writing a single line of code. That relationship between specification and implementation is what **Goal & Direction** means in this course.
#
# See you in class.
